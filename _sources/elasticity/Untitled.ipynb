# %% [markdown]
# # Gallery
#
# some more examples can be found here:
#
# * [NGS24 usermeeting](https://docu.ngsolve.org/ngs24/SaS/nonlinearelasticity.html)
#
# * [Meta-material](https://jschoeberl.github.io/IntroSC/PDEs/elasticity/metamaterial_thick.html)
